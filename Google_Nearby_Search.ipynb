# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from Config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "-9.8000, -139.0333"}
# Use base URL to search for hotels.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params = params).json()
hotels
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -9.7952289, 'lng': -139.0305256},
#     'viewport': {'northeast': {'lat': -9.793859019708496,
#       'lng': -139.0290940697085},
#      'southwest': {'lat': -9.7965569802915, 'lng': -139.0317920302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Villa Enata',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1364,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107138465294965223459">Villa Enata</a>'],
#      'photo_reference': 'ATtYBwLvXD12h0M2RMyHg9QP3bA3Wu8mXBY6VWSQmr8CQuQ9ZcAEcG13pUBFcX_JkCUC3LXqBIciRUIEfSEPJCds6YvUbpRkljfAgzIW8Jet783HN7ml2e1kiYIbMi4RdyyN5pFdOYHYTfkty4WGUlpBE1Cjpis_JbW2ryk4FXJnXC5yVgMI',
#      'width': 2048}],
#    'place_id': 'ChIJ6TdkUOUhN3YRm5q1WA7YE4U',
#    'plus_code': {'compound_code': '6X39+WQ Hiva Oa, French Polynesia',
#     'global_code': '64226X39+WQ'},
#    'rating': 4.8,
#    'reference': 'ChIJ6TdkUOUhN3YRm5q1WA7YE4U',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': 'Domaine Emile Rauzy,Tahauku'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -9.8008674, 'lng': -139.0324028},
#     'viewport': {'northeast': {'lat': -9.799512769708498,
#       'lng': -139.0313031697085},
#      'southwest': {'lat': -9.802210730291502, 'lng': -139.0340011302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pension Temetiu Village',
#    'photos': [{'height': 3912,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100753586291945627781">Antoine G.</a>'],
#      'photo_reference': 'ATtYBwKZzyFVg2B0_KfP5Znf9B21RqZTH_7SYElsYOqyx1M7ya-W_Gvf1CmjX55PT1-A0RPUZYghY3SSvWuBVs3Aa8JN7CR37sYqrrvw17KT5Vhd8rIrk5YShXtjUtPs1Q3opNvZj79-RhciNlke-VGVG8GbpRAtPtRTDayajAWIRLNlra4i',
#      'width': 5687}],
#    'place_id': 'ChIJc0T5Fv0hN3YRBLZPSycyN9Y',
#    'plus_code': {'compound_code': '5XX9+M2 Hiva Oa, French Polynesia',
#     'global_code': '64225XX9+M2'},
#    'rating': 4.4,
#    'reference': 'ChIJc0T5Fv0hN3YRBLZPSycyN9Y',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 31,
#    'vicinity': ''},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -9.7984419, 'lng': -139.0324548},
#     'viewport': {'northeast': {'lat': -9.797085919708497,
#       'lng': -139.0310559197085},
#      'southwest': {'lat': -9.799783880291502, 'lng': -139.0337538802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Maison d’hôtesTahauku',
#    'place_id': 'ChIJo_GYDrUhN3YRpPZ6fPyWV_s',
#    'plus_code': {'compound_code': '6X29+J2 Hiva Oa, French Polynesia',
#     'global_code': '64226X29+J2'},
#    'reference': 'ChIJo_GYDrUhN3YRpPZ6fPyWV_s',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Unnamed Road'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -9.803152299999999, 'lng': -139.0379031},
#     'viewport': {'northeast': {'lat': -9.8018448697085,
#       'lng': -139.0366015197085},
#      'southwest': {'lat': -9.804542830291505, 'lng': -139.0392994802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pension Ozanne',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112933441302223628084">Manuel Serra</a>'],
#      'photo_reference': 'ATtYBwI2HowMNw6NqXsF1DcTmZusEp-m2fUq4vig6IAofy-45w68EnAZiEvhVbOEoXLO1aPEroPXXWcLlRatzajKdZHegsjYwdH7FVsVNS3QoSkvfT0zyWw7N_PCvnuUxXHcZF9oRKfqb5vIfIjLHdx7aHRKSfQENr4XPpx-_CrsY3jcywD_',
#      'width': 4032}],
#    'place_id': 'ChIJHxAe7vwhN3YRO6v-fjlQWb4',
#    'plus_code': {'compound_code': '5XW6+PR Hiva Oa, French Polynesia',
#     'global_code': '64225XW6+PR'},
#    'rating': 4.4,
#    'reference': 'ChIJHxAe7vwhN3YRO6v-fjlQWb4',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 9,
#    'vicinity': ''},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -9.795333, 'lng': -139.0296412},
#     'viewport': {'northeast': {'lat': -9.793963319708498,
#       'lng': -139.0282809697085},
#      'southwest': {'lat': -9.796661280291502, 'lng': -139.0309789302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Inake Lodge',
#    'place_id': 'ChIJhyc7DUshN3YRl0iMslpubok',
#    'plus_code': {'compound_code': '6X3C+V4 Hiva Oa, French Polynesia',
#     'global_code': '64226X3C+V4'},
#    'rating': 4,
#    'reference': 'ChIJhyc7DUshN3YRl0iMslpubok',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': 'Unnamed Road, Hiva Oa'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -9.804706999999999, 'lng': -139.036941},
#     'viewport': {'northeast': {'lat': -9.803335369708496,
#       'lng': -139.0355610197085},
#      'southwest': {'lat': -9.8060333302915, 'lng': -139.0382589802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Relais Moehau',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1365,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109271372844993598375">Théophile Cordiez</a>'],
#      'photo_reference': 'ATtYBwICKFx1ymSp-2qoApnq63IFPSamxYwoGPMMLQLOPSuT_sY_SffwOzrZHTIY60aZ94DZfUnKkTnIUp7ZSLQ_9pGy4LOm42gY-12mY4IX3y7ZDPkknUHDq0AZm0cHO0bXQ6QAn3M5TbbfcKr8OYCyoxaePZ8uBIvzGJ88apFTr1AkMb3X',
#      'width': 720}],
#    'place_id': 'ChIJddJa818hN3YRiHh6rcs_VTM',
#    'plus_code': {'compound_code': '5XW7+46 Hiva Oa, French Polynesia',
#     'global_code': '64225XW7+46'},
#    'rating': 3.8,
#    'reference': 'ChIJddJa818hN3YRiHh6rcs_VTM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 4,
#    'vicinity': '98741'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -9.8050763, 'lng': -139.036455},
#     'viewport': {'northeast': {'lat': -9.803751969708498,
#       'lng': -139.0351511697085},
#      'southwest': {'lat': -9.806449930291503, 'lng': -139.0378491302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Chez Georges et Tahu',
#    'photos': [{'height': 683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112734349474362812282">Georges GRAMONT</a>'],
#      'photo_reference': 'ATtYBwLKqxbctvRmS3aZwuOzmyTTTkaTqPrFpxNaXDn3k_-ED37HItfOgWo5tsHDGswMOI98zNAjqhcZEUXrhK2GpfJAW6jaEn2_HBQFpzgtXH07fKZKkWgDVsipZjl_Uj8sNme2FvCAu5X21z8znk7bdKUo4woc70ClSjzNfROLTpTfV6AG',
#      'width': 1024}],
#    'place_id': 'ChIJc0T5Fv0hN3YRohA1Z49zEGQ',
#    'plus_code': {'compound_code': '5XV7+XC Hiva Oa, French Polynesia',
#     'global_code': '64225XV7+XC'},
#    'rating': 4,
#    'reference': 'ChIJc0T5Fv0hN3YRohA1Z49zEGQ',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 14,
#    'vicinity': ''},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -9.803798, 'lng': -139.026675},
#     'viewport': {'northeast': {'lat': -9.8024185197085,
#       'lng': -139.0253844697085},
#      'southwest': {'lat': -9.805116480291504, 'lng': -139.0280824302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'CHALETS HANAKEE',
#    'photos': [{'height': 2448,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107213774069173427262">Claire Talvard</a>'],
#      'photo_reference': 'ATtYBwKUIxSFRFaMqUizMgWwDgTq_URQZAxXq2moFsjk_hK4dRcLUC7h5sgWhdfltFk8cTMgUrAs65cDmveSI8_3JelSkO8oOFkMvPBD4B0WaKDnt2Kq5jZpKChyT2vnvb-KCX1CJMcAFfBLGlu_Kq4zSqwnja5r-oh6TUX4nqj6-GiQbo2H',
#      'width': 3264}],
#    'place_id': 'ChIJWU5mUPEhN3YR-1rbFNJuNRo',
#    'plus_code': {'compound_code': '5XWF+F8 Hiva Oa, French Polynesia',
#     'global_code': '64225XWF+F8'},
#    'rating': 4.6,
#    'reference': 'ChIJWU5mUPEhN3YR-1rbFNJuNRo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': ''},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -9.8078769, 'lng': -139.0303352},
#     'viewport': {'northeast': {'lat': -9.806552619708498,
#       'lng': -139.0289095697085},
#      'southwest': {'lat': -9.809250580291502, 'lng': -139.0316075302915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Simplicité Marquises',
#    'opening_hours': {'open_now': False},
#    'place_id': 'ChIJk_642yQhN3YRXq9lyadHUqY',
#    'plus_code': {'compound_code': '5XR9+RV Hiva Oa, French Polynesia',
#     'global_code': '64225XR9+RV'},
#    'reference': 'ChIJk_642yQhN3YRXq9lyadHUqY',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Hiva Oa'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -9.8042137, 'lng': -139.0256647},
#     'viewport': {'northeast': {'lat': -9.802860119708496,
#       'lng': -139.0241524197085},
#      'southwest': {'lat': -9.805558080291501, 'lng': -139.0268503802915}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'name': 'Pension Joséphine',
#    'place_id': 'ChIJmco7mswhN3YRuo7Hb6hUS24',
#    'plus_code': {'compound_code': '5XWF+8P Hiva Oa, French Polynesia',
#     'global_code': '64225XWF+8P'},
#    'reference': 'ChIJmco7mswhN3YRuo7Hb6hUS24',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'vicinity': 'Hiva Oa'}],
#  'status': 'OK'}

# %%
hotels["results"][0]["name"]
# Out:
# 'Villa Enata'
